# %% [markdown]
# Task 1 :
# ➔Gravitational force is the attractive force that exists between two masses.
# It can be calculated by using the following formula:![image.png](data:image/png;base64,...)

# %%
# Gravitational Constant
G = 6.67E-11
# Mass of the first
M1 = float( input("please Enter the Mass of the first \t"))
# Mass of the second
M2 = float( input("please Enter the Mass of the second \t"))
# the distance between them
R = float( input("please Enter the distance between \t"))
# Gravitational force
Fg = ((G * M1 * M2)/(R**2))
print ("Gravitational force is \t", Fg)
# Out:
# please Enter the Mass of the first 	6.0E24
# please Enter the Mass of the second 	7.34E22
# please Enter the distance between 	3.84E8
# Gravitational force is 	 1.9920979817708333e+20
